# %%
import pandas as pd
import numpy as np

# %%
names = ['철수', '영이', '길동', '미영', '순이', '철이']
lectures = ['국어', '영어', '수학']
scores = [[84,87,78],[21,15,84],[87,84,76],[100,87,99],[59,99,59],[46,77,56]]
d1 = pd.DataFrame(scores, index=names, columns=lectures)
d1.to_excel('c:/data/scores.xls')

# %%
df = pd.read_excel('c:/data/scores.xls', index_col=0)

# %%
df
# Out:
#      국어  영어  수학
# 철수   84  87  78
# 영이   21  15  84
# 길동   87  84  76
# 미영  100  87  99
# 순이   59  99  59
# 철이   46  77  56

# %%
df2 = pd.read_excel('c:/data/scores.xls', usecols=[2,3])
df2
# Out:
#    영어  수학
# 0  87  78
# 1  15  84
# 2  84  76
# 3  87  99
# 4  99  59
# 5  77  56

# %%
df3 = pd.read_excel('c:/data/scores.xls', header=0)
df3
# Out:
#   Unnamed: 0   국어  영어  수학
# 0         철수   84  87  78
# 1         영이   21  15  84
# 2         길동   87  84  76
# 3         미영  100  87  99
# 4         순이   59  99  59
# 5         철이   46  77  56

# %%
d1.to_csv('c:/data/scores.csv', encoding=euc-kr)

# %%
dff= pd.read_csv('c:/data/scores.csv')
dff
# Out:
#   Unnamed: 0   국어  영어  수학
# 0         철수   84  87  78
# 1         영이   21  15  84
# 2         길동   87  84  76
# 3         미영  100  87  99
# 4         순이   59  99  59
# 5         철이   46  77  56

# %%
names = ['stu1', 'stu2', 'stu3', 'stu4', 'stu5', 'stu6']
lectures = ['kor', 'eng', 'math']
scores = [[84,87,78],[21,15,84],[87,84,76],[100,87,99],[59,99,59],[46,77,56]]
d1 = pd.DataFrame(scores, index=names, columns=lectures)
d1.to_json('c:/data/scores.jason')

# %%
df=pd.read_json('c:/data/scores.jason')
df
# Out:
#       kor  eng  math
# stu1   84   87    78
# stu2   21   15    84
# stu3   87   84    76
# stu4  100   87    99
# stu5   59   99    59
# stu6   46   77    56

# %%
d1.to_html('c:/data/scores.html')

# %% [markdown]
# ==========================================================================================================

# %%
import sqlite3

# %%
con = sqlite3.connect('c:/sqlite/testdb')

# %%
d1.to_sql('scores', con, index_label='name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-67a36f3be1e2> in <module>
# ----> 1 d1.to_sql('scores', con, index_label='name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ...

# %%
d2 = pd.read_sql('select * from scores', con)

# %%
d2
# Out:
#    name  kor  eng  math
# 0  stu1   84   87    78
# 1  stu2   21   15    84
# 2  stu3   87   84    76
# 3  stu4  100   87    99
# 4  stu5   59   99    59
# 5  stu6   46   77    56

# %%
d3 = pd.read_sql('select kor, eng from scores where math>=70', con)
d3
# Out:
#    kor  eng
# 0   84   87
# 1   21   15
# 2   87   84
# 3  100   87

# %%
pop = pd.read_excel('c:/data/pop_in_seoul1.xls')
pop

pop1 = pd.read_excel('c:/data/pop_in_seoul1.xls', usecols=[1,3,6,9,13], header = 2)
pop1

pop1.columns = ['구별','인구수','한국인','외국인','고령인']

pop1

pop1.set_index('구별', inplace=True)

pop1

pop1.drop('합계', inplace = True)
pop1
# Out:
#           기간   자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0         기간   자치구       세대        합계       합계       합계      한국인      한국인
# 1         기간   자치구       세대         계       남자       여자        계       남자
# 2   2019.1/4    합계  4290922  10054979  4909387  5145592  9770216  4772134
# 3   2019.1/4   종로구    73914    162913    78963    83950   152778    74536
# 4   2019.1/4    중구    61800    135836    66720    69116   125942    61992
# 5   2019.1/4   용산구   109413    245139   119597   125542   229168   110626
# 6   2019.1/4   성동구   137247    314608   154011   160597   306404   150287
# 7   2019.1/4   광진구   163460    370658   179162   191496   354873   172361
# 8   2019.1/4  동대문구   162228    363262   179100   184162   346750   172784
# 9   2019.1/4   중랑구   181182    407211   201808   205403   402203   199730
# 10  2019.1/4   성북구   188670    450021   217400   232621   438245   212830
# 11  2019.1/4   강북구   143663    321151   156525   164626   317386   155075
# ...

# %%
pop1 = pd.read_excel('c:/data/pop_in_seoul1.xls', usecols=[1,3,6,9,13], header = 2)
pop1
# Out:
#      자치구         계      계.1     계.2  65세이상고령자
# 0     합계  10054979  9770216  284763   1436125
# 1    종로구    162913   152778   10135     26981
# 2     중구    135836   125942    9894     22421
# 3    용산구    245139   229168   15971     38049
# 4    성동구    314608   306404    8204     43076
# 5    광진구    370658   354873   15785     46288
# 6   동대문구    363262   346750   16512     57570
# 7    중랑구    407211   402203    5008     62789
# 8    성북구    450021   438245   11776     68612
# 9    강북구    321151   317386    3765     58858
# 10   도봉구    340089   337820    2269     56742
# 11   노원구    545486   541174    4312     78170
# 12   은평구    488713   484274    4439     78406
# 13  서대문구    324604   311771   12833     51085
# 14   마포구    386571   375106   11465     51293
# 15   양천구    466622   462599    4023     58930
# 16   강서구    602886   596287    6599     80903
# 17   구로구    438889   404726   34163     63017
# 18   금천구    254244   233981   20263     36301
# ...

# %%
pop1.columns = ['구별','인구수','한국인','외국인','고령인']

# %%
pop1
# Out:
#       구별       인구수      한국인     외국인      고령인
# 0     합계  10054979  9770216  284763  1436125
# 1    종로구    162913   152778   10135    26981
# 2     중구    135836   125942    9894    22421
# 3    용산구    245139   229168   15971    38049
# 4    성동구    314608   306404    8204    43076
# 5    광진구    370658   354873   15785    46288
# 6   동대문구    363262   346750   16512    57570
# 7    중랑구    407211   402203    5008    62789
# 8    성북구    450021   438245   11776    68612
# 9    강북구    321151   317386    3765    58858
# 10   도봉구    340089   337820    2269    56742
# 11   노원구    545486   541174    4312    78170
# 12   은평구    488713   484274    4439    78406
# 13  서대문구    324604   311771   12833    51085
# 14   마포구    386571   375106   11465    51293
# 15   양천구    466622   462599    4023    58930
# 16   강서구    602886   596287    6599    80903
# 17   구로구    438889   404726   34163    63017
# 18   금천구    254244   233981   20263    36301
# 19  영등포구    404556   368824   35732    56463
# ...

# %%
pop1.set_index('구별', inplace=True)

# %%
pop1
# Out:
#            인구수      한국인     외국인      고령인
# 구별
# 합계    10054979  9770216  284763  1436125
# 종로구     162913   152778   10135    26981
# 중구      135836   125942    9894    22421
# 용산구     245139   229168   15971    38049
# 성동구     314608   306404    8204    43076
# 광진구     370658   354873   15785    46288
# 동대문구    363262   346750   16512    57570
# 중랑구     407211   402203    5008    62789
# 성북구     450021   438245   11776    68612
# 강북구     321151   317386    3765    58858
# 도봉구     340089   337820    2269    56742
# 노원구     545486   541174    4312    78170
# 은평구     488713   484274    4439    78406
# 서대문구    324604   311771   12833    51085
# 마포구     386571   375106   11465    51293
# 양천구     466622   462599    4023    58930
# 강서구     602886   596287    6599    80903
# 구로구     438889   404726   34163    63017
# 금천구     254244   233981   20263    36301
# 영등포구    404556   368824   35732    56463
# 동작구     412031   398886   13145    60462
# 관악구     520645   502615   18030    73005
# ...

# %%
pop1.drop('합계', inplace = True)
pop1
# Out:
#          인구수     한국인    외국인    고령인
# 구별
# 종로구   162913  152778  10135  26981
# 중구    135836  125942   9894  22421
# 용산구   245139  229168  15971  38049
# 성동구   314608  306404   8204  43076
# 광진구   370658  354873  15785  46288
# 동대문구  363262  346750  16512  57570
# 중랑구   407211  402203   5008  62789
# 성북구   450021  438245  11776  68612
# 강북구   321151  317386   3765  58858
# 도봉구   340089  337820   2269  56742
# 노원구   545486  541174   4312  78170
# 은평구   488713  484274   4439  78406
# 서대문구  324604  311771  12833  51085
# 마포구   386571  375106  11465  51293
# 양천구   466622  462599   4023  58930
# 강서구   602886  596287   6599  80903
# 구로구   438889  404726  34163  63017
# 금천구   254244  233981  20263  36301
# 영등포구  404556  368824  35732  56463
# 동작구   412031  398886  13145  60462
# 관악구   520645  502615  18030  73005
# 서초구   437007  432762   4245  55366
# 강남구   546875  541854   5021  68104
# 송파구   685361  678521   6840  83492
# 강동구   429601  425267   4334  59742

# %%
pop1['한국인비율(%)'] = pop1['한국인']/pop1['인구수']*100

# %%
pop1
# Out:
#          인구수     한국인    외국인    고령인   한국인비율(%)
# 구별
# 종로구   162913  152778  10135  26981  93.778888
# 중구    135836  125942   9894  22421  92.716217
# 용산구   245139  229168  15971  38049  93.484921
# 성동구   314608  306404   8204  43076  97.392310
# 광진구   370658  354873  15785  46288  95.741357
# 동대문구  363262  346750  16512  57570  95.454520
# 중랑구   407211  402203   5008  62789  98.770171
# 성북구   450021  438245  11776  68612  97.383233
# 강북구   321151  317386   3765  58858  98.827654
# 도봉구   340089  337820   2269  56742  99.332822
# 노원구   545486  541174   4312  78170  99.209512
# 은평구   488713  484274   4439  78406  99.091696
# 서대문구  324604  311771  12833  51085  96.046568
# 마포구   386571  375106  11465  51293  97.034180
# 양천구   466622  462599   4023  58930  99.137846
# 강서구   602886  596287   6599  80903  98.905432
# 구로구   438889  404726  34163  63017  92.216027
# 금천구   254244  233981  20263  36301  92.030097
# 영등포구  404556  368824  35732  56463  91.167601
# ...

# %%
pop1['외국인비율(%)'] = (pop1.외국인/pop1.인구수)*100
pop1
# Out:
#          인구수     한국인    외국인    고령인   한국인비율(%)  외국인비율(%)
# 구별
# 종로구   162913  152778  10135  26981  93.778888  6.221112
# 중구    135836  125942   9894  22421  92.716217  7.283783
# 용산구   245139  229168  15971  38049  93.484921  6.515079
# 성동구   314608  306404   8204  43076  97.392310  2.607690
# 광진구   370658  354873  15785  46288  95.741357  4.258643
# 동대문구  363262  346750  16512  57570  95.454520  4.545480
# 중랑구   407211  402203   5008  62789  98.770171  1.229829
# 성북구   450021  438245  11776  68612  97.383233  2.616767
# 강북구   321151  317386   3765  58858  98.827654  1.172346
# 도봉구   340089  337820   2269  56742  99.332822  0.667178
# 노원구   545486  541174   4312  78170  99.209512  0.790488
# 은평구   488713  484274   4439  78406  99.091696  0.908304
# 서대문구  324604  311771  12833  51085  96.046568  3.953432
# 마포구   386571  375106  11465  51293  97.034180  2.965820
# 양천구   466622  462599   4023  58930  99.137846  0.862154
# 강서구   602886  596287   6599  80903  98.905432  1.094568
# ...

# %%
pop1['고령인비율(%)'] = (pop1.고령인/pop1.인구수)*100
pop1
# Out:
#          인구수     한국인    외국인    고령인   한국인비율(%)  외국인비율(%)   고령인비율(%)
# 구별
# 종로구   162913  152778  10135  26981  93.778888  6.221112  16.561600
# 중구    135836  125942   9894  22421  92.716217  7.283783  16.505934
# 용산구   245139  229168  15971  38049  93.484921  6.515079  15.521398
# 성동구   314608  306404   8204  43076  97.392310  2.607690  13.691960
# 광진구   370658  354873  15785  46288  95.741357  4.258643  12.488062
# 동대문구  363262  346750  16512  57570  95.454520  4.545480  15.848066
# 중랑구   407211  402203   5008  62789  98.770171  1.229829  15.419279
# 성북구   450021  438245  11776  68612  97.383233  2.616767  15.246400
# 강북구   321151  317386   3765  58858  98.827654  1.172346  18.327204
# 도봉구   340089  337820   2269  56742  99.332822  0.667178  16.684456
# 노원구   545486  541174   4312  78170  99.209512  0.790488  14.330340
# 은평구   488713  484274   4439  78406  99.091696  0.908304  16.043363
# 서대문구  324604  311771  12833  51085  96.046568  3.953432  15.737637
# ...

# %%
pop2 = pop1.sort_values(by = '인구수', ascending = False)
pop2.tail(5)
# Out:
#         인구수     한국인    외국인    고령인   한국인비율(%)  외국인비율(%)   고령인비율(%)
# 구별
# 성동구  314608  306404   8204  43076  97.392310  2.607690  13.691960
# 금천구  254244  233981  20263  36301  92.030097  7.969903  14.278016
# 용산구  245139  229168  15971  38049  93.484921  6.515079  15.521398
# 종로구  162913  152778  10135  26981  93.778888  6.221112  16.561600
# 중구   135836  125942   9894  22421  92.716217  7.283783  16.505934

# %%
pop2 = pop1.sort_values(by = '외국인', ascending = False)
pop2
# Out:
#          인구수     한국인    외국인    고령인   한국인비율(%)  외국인비율(%)   고령인비율(%)
# 구별
# 영등포구  404556  368824  35732  56463  91.167601  8.832399  13.956782
# 구로구   438889  404726  34163  63017  92.216027  7.783973  14.358300
# 금천구   254244  233981  20263  36301  92.030097  7.969903  14.278016
# 관악구   520645  502615  18030  73005  96.536988  3.463012  14.022030
# 동대문구  363262  346750  16512  57570  95.454520  4.545480  15.848066
# 용산구   245139  229168  15971  38049  93.484921  6.515079  15.521398
# 광진구   370658  354873  15785  46288  95.741357  4.258643  12.488062
# 동작구   412031  398886  13145  60462  96.809706  3.190294  14.674139
# 서대문구  324604  311771  12833  51085  96.046568  3.953432  15.737637
# 성북구   450021  438245  11776  68612  97.383233  2.616767  15.246400
# 마포구   386571  375106  11465  51293  97.034180  2.965820  13.268714
# 종로구   162913  152778  10135  26981  93.778888  6.221112  16.561600
# 중구    135836  125942   9894  22421  92.716217  7.283783  16.505934
# ...

# %%
pop2 = pop1.sort_values(by = '외국인비율(%)', ascending = False)
pop2
# Out:
#          인구수     한국인    외국인    고령인   한국인비율(%)  외국인비율(%)   고령인비율(%)
# 구별
# 영등포구  404556  368824  35732  56463  91.167601  8.832399  13.956782
# 금천구   254244  233981  20263  36301  92.030097  7.969903  14.278016
# 구로구   438889  404726  34163  63017  92.216027  7.783973  14.358300
# 중구    135836  125942   9894  22421  92.716217  7.283783  16.505934
# 용산구   245139  229168  15971  38049  93.484921  6.515079  15.521398
# 종로구   162913  152778  10135  26981  93.778888  6.221112  16.561600
# 동대문구  363262  346750  16512  57570  95.454520  4.545480  15.848066
# 광진구   370658  354873  15785  46288  95.741357  4.258643  12.488062
# 서대문구  324604  311771  12833  51085  96.046568  3.953432  15.737637
# 관악구   520645  502615  18030  73005  96.536988  3.463012  14.022030
# 동작구   412031  398886  13145  60462  96.809706  3.190294  14.674139
# 마포구   386571  375106  11465  51293  97.034180  2.965820  13.268714
# 성북구   450021  438245  11776  68612  97.383233  2.616767  15.246400
# ...

# %%
pop2 = pop1.sort_values(by = '고령인비율(%)', ascending = True)
pop2
# Out:
#          인구수     한국인    외국인    고령인   한국인비율(%)  외국인비율(%)   고령인비율(%)
# 구별
# 송파구   685361  678521   6840  83492  99.001986  0.998014  12.182193
# 강남구   546875  541854   5021  68104  99.081874  0.918126  12.453303
# 광진구   370658  354873  15785  46288  95.741357  4.258643  12.488062
# 양천구   466622  462599   4023  58930  99.137846  0.862154  12.629066
# 서초구   437007  432762   4245  55366  99.028620  0.971380  12.669362
# 마포구   386571  375106  11465  51293  97.034180  2.965820  13.268714
# 강서구   602886  596287   6599  80903  98.905432  1.094568  13.419287
# 성동구   314608  306404   8204  43076  97.392310  2.607690  13.691960
# 강동구   429601  425267   4334  59742  98.991157  1.008843  13.906392
# 영등포구  404556  368824  35732  56463  91.167601  8.832399  13.956782
# 관악구   520645  502615  18030  73005  96.536988  3.463012  14.022030
# 금천구   254244  233981  20263  36301  92.030097  7.969903  14.278016
# 노원구   545486  541174   4312  78170  99.209512  0.790488  14.330340
# ...

# %% [markdown]
# ==================================================================================================

# %%
d1
# Out:
#       kor  eng  math
# stu1   84   87    78
# stu2   21   15    84
# stu3   87   84    76
# stu4  100   87    99
# stu5   59   99    59
# stu6   46   77    56

# %%
d1.mean()
# Out:
# kor     66.166667
# eng     74.833333
# math    75.333333
# dtype: float64

# %%
d1.loc['avg'] = d1.mean()
d1
# Out:
#              kor        eng       math
# stu1   84.000000  87.000000  78.000000
# stu2   21.000000  15.000000  84.000000
# stu3   87.000000  84.000000  76.000000
# stu4  100.000000  87.000000  99.000000
# stu5   59.000000  99.000000  59.000000
# stu6   46.000000  77.000000  56.000000
# avg    66.166667  74.833333  75.333333

# %%
d1 = d1.drop('avg')

# %%
d1
# Out:
#         kor   eng  math
# stu1   84.0  87.0  78.0
# stu2   21.0  15.0  84.0
# stu3   87.0  84.0  76.0
# stu4  100.0  87.0  99.0
# stu5   59.0  99.0  59.0
# stu6   46.0  77.0  56.0

# %%
d1.median()
# Out:
# kor     71.5
# eng     85.5
# math    77.0
# dtype: float64

# %%
d1.min()
# Out:
# kor     21.0
# eng     15.0
# math    56.0
# dtype: float64

# %%
d1.max()
# Out:
# kor     100.0
# eng      99.0
# math     99.0
# dtype: float64

# %%
d1[['kor','math']].min()
# Out:
# kor     21.0
# math    56.0
# dtype: float64

# %%
pop1.mean()
# Out:
# 인구수         402199.160000
# 한국인         390808.640000
# 외국인          11390.520000
# 고령인          57445.000000
# 한국인비율(%)        96.686855
# 외국인비율(%)         3.313145
# 고령인비율(%)        14.568931
# dtype: float64

# %%
pop1.인구수.min()
# Out:
# 135836

# %%
pop1.인구수.max()
# Out:
# 685361

# %%
pop1[['인구수','고령인']].corr()
# Out:
#           인구수       고령인
# 인구수  1.000000  0.942086
# 고령인  0.942086  1.000000

# %%
d1
# Out:
#         kor   eng  math
# stu1   84.0  87.0  78.0
# stu2   21.0  15.0  84.0
# stu3   87.0  84.0  76.0
# stu4  100.0  87.0  99.0
# stu5   59.0  99.0  59.0
# stu6   46.0  77.0  56.0

# %%
d1['kor'].astype('int')
# Out:
# stu1     84
# stu2     21
# stu3     87
# stu4    100
# stu5     59
# stu6     46
# Name: kor, dtype: int32

# %%
d1
# Out:
#         kor   eng  math
# stu1   84.0  87.0  78.0
# stu2   21.0  15.0  84.0
# stu3   87.0  84.0  76.0
# stu4  100.0  87.0  99.0
# stu5   59.0  99.0  59.0
# stu6   46.0  77.0  56.0

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips_miss = tips.head(10)
tips_miss.iloc[[1,3,5,7],0] = 'missing'
print(tips_miss)
# Out:
#   total_bill   tip     sex smoker  day    time  size
# 0      16.99  1.01  Female     No  Sun  Dinner     2
# 1    missing  1.66    Male     No  Sun  Dinner     3
# 2      21.01  3.50    Male     No  Sun  Dinner     3
# 3    missing  3.31    Male     No  Sun  Dinner     2
# 4      24.59  3.61  Female     No  Sun  Dinner     4
# 5    missing  4.71    Male     No  Sun  Dinner     4
# 6       8.77  2.00    Male     No  Sun  Dinner     2
# 7    missing  3.12    Male     No  Sun  Dinner     4
# 8      15.04  1.96    Male     No  Sun  Dinner     2
# 9      14.78  3.23    Male     No  Sun  Dinner     2
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
print(tips.dtypes)
print(tips_miss.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
# total_bill      object
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips_miss['total_bill'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-7ff0308f74d4> in <module>
# ----> 1 tips_miss['total_bill'].astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
tips_miss['total_bill'] = pd.to_numeric(tips_miss['total_bill'], errors = 'coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(tips_miss.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips_miss
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1         NaN  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3         NaN  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5         NaN  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7         NaN  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips_miss['total_bill'] = pd.to_numeric(tips_miss['total_bill'], errors = 'coerce', downcast = 'float')
print(tips_miss.dtypes)
# Out:
# total_bill     float32
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
print(tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB
# None

# %%
tips['sex'] = tips['sex'].astype('str')

# %%
print(tips.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(3), float64(2), int64(1), object(1)
# memory usage: 8.8+ KB
# None

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic['deck'] = titanic['deck'].astype('str')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           891 non-null object
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(6)
# memory usage: 86.4+ KB

# %%
titanic['deck'] = titanic['deck'].astype('category')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           891 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
titanic1 = titanic[['sex','fare','class','alive']]

# %%
titanic1.head(10)
# Out:
#       sex     fare   class alive
# 0    male   7.2500   Third    no
# 1  female  71.2833   First   yes
# 2  female   7.9250   Third   yes
# 3  female  53.1000   First   yes
# 4    male   8.0500   Third    no
# 5    male   8.4583   Third    no
# 6    male  51.8625   First    no
# 7    male  21.0750   Third    no
# 8  female  11.1333   Third   yes
# 9  female  30.0708  Second   yes

# %%
titanic1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
# sex      891 non-null object
# fare     891 non-null float64
# class    891 non-null category
# alive    891 non-null object
# dtypes: category(1), float64(1), object(2)
# memory usage: 22.0+ KB

# %%
titanic1['sex'] = titanic1['sex'].astype('float', errors = 'ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
titanic1[['sex','alive']].corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
